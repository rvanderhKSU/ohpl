# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from keras.applications import DenseNet121
from keras.callbacks import Callback, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
import tensorflow as tf
from tqdm import tqdm

# %matplotlib inline
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %% [markdown]
# # Edited Point Loss

# %%
def hp_ordering_loss(y_true, y_pred):

    """ Evaluate the ordinal loss of the predictions y_pred.
        
        Parameters
        ----------
        y_true : array-like
        y_pred : array-like
        
        Returns
        -------
        loss: float
            A non-negative floating point value (best value is 0.0)
            
        Usage
        -------
        loss = hp_ordering_loss([4,1,2,0,4,2,1], [6.0,3.1,5.2,1.0,4.0,2.2,3.7])
        print('Loss: ', loss.numpy())  # Loss: 2.8
        
        Usage with the `compile` API:
       
        ```python
        model = tf.keras.Model(inputs, outputs)
        model.compile(loss=hp_ordering_loss, optimizer='adam', loss=hp_ordering_loss)
        ```
        
    """

    y_pred = tf.convert_to_tensor(y_pred)
    y_true = tf.dtypes.cast(y_true, y_pred.dtype)
    y_pred = tf.reshape(tf.transpose(y_pred),[-1,1])

    # one hot vector for y_true
    ords, idx = tf.unique(tf.reshape(y_true, [-1])) 
    num = tf.shape(ords)[0]
    y_true_1hot = tf.one_hot(idx, num)

    # mean distance for each class
    yO = tf.transpose(y_pred) @ y_true_1hot
    yc = tf.reduce_sum(y_true_1hot,0)
    class_mean = tf.divide(yO,yc)  

    # min. distance
    ords = tf.dtypes.cast(ords, tf.float32)
    ords0 = tf.reshape(ords, [-1,1])
    ords1 = tf.reshape(ords, [1,-1])
    
    min_distance = tf.subtract(ords0, ords1)
    # apply ReLU
    min_distance = tf.nn.relu (min_distance)
    
    # keeps min. distance
    keep = tf.minimum(min_distance,1)

    # distance to centroid     
    class_mean0 = tf.reshape(class_mean, [-1,1])
    class_mean1 = tf.reshape(class_mean, [1,-1])
    class_mean = tf.subtract(class_mean0, class_mean1)  
    # apply ReLU    
    class_mean = tf.nn.relu(class_mean)
    centroid_distance = tf.multiply(keep, class_mean)
    
    hp_ordering_loss = tf.subtract(min_distance,centroid_distance)
    # apply ReLU
    hp_ordering_loss = tf.nn.relu(hp_ordering_loss)
        
    return tf.reduce_sum(hp_ordering_loss)


def hp_point_loss(y_true, y_pred, L, U, margin=0.1):
    """ Evaluate the point loss of the predictions y_pred.

        Parameters
        ----------
        y_true : array-like
        y_pred : array-like
        minlabel : integer
        maxlabel : integer
        margin : float

        Returns
        -------
        loss: float
        A non-negative floating point value (best value is 0.0)
        
        Usage
        -------
        loss = hp_point_loss([4,1,2,0,4,2,1], [6.0,3.1,5.2,1.0,4.0,2.2,3.7],0,4,.3)
        print('Loss: ', loss.numpy())  # Loss: 3.1
        
        
        Usage with the `compile` API:
        
        ```python
        
        Example Keras wrapper for hp_point_loss:
        
        def get_ohpl_wrapper (min_label, max_label, margin):
            def ohpl(y_true, y_pred):
                return hp_point_loss(y_true, y_pred, min_label, max_label, margin)
            return ohpl

        point_loss = get_ohpl_wrapper(0,4,0.01)
        
        model = tf.keras.Model(inputs, outputs)
        model.compile(loss=ohpl_point_loss, optimizer='adam', loss=ohpl_point_loss)
        ```
        
    """
    
    y_pred = tf.reshape(tf.convert_to_tensor(y_pred), [-1,1])
    y_true = tf.cast(y_true, dtype=tf.float32)
    
    upper = tf.reshape(tf.constant(U, dtype=tf.float32), [-1,1])
    lower = tf.reshape(tf.constant(L, dtype=tf.float32), [-1,1])
    uthreshold = tf.matmul(y_true, upper, name='upper_MM')
    lthreshold = tf.matmul(y_true, lower, name='lower_MM')

    upper_loss = tf.nn.relu(tf.subtract(y_pred, uthreshold))
    lower_loss = tf.nn.relu(tf.subtract(lthreshold, y_pred))
    
    hp_point_loss = tf.add(upper_loss, lower_loss)
    
    return tf.reduce_sum(hp_point_loss)
    
    """    
        References
        ----------
        .. [1] Vanderheyden, Bob and Ying Xie. Ordinal Hyperplane Loss. (2018). 
           2018 IEEE International Conference on Big Data (Big Data), 
           2018 IEEE International Conference On, 2337. https://doi-org.proxy.kennesaw.edu/10.1109/BigData.2018.8622079
    """

# %%
np.random.seed(2019)
tf.set_random_seed(2019)

# %%
train_df = pd.read_csv('./training.csv')
test_df = pd.read_csv('./testing.csv')
print(train_df.shape)
print(test_df.shape)
train_df.head()
# Out:
# (12603, 2)
# (3153, 2)
#       data  label
# 0  0_22440      0
# 1   0_6509      0
# 2  0_15699      0
# 3  0_32913      0
# 4  0_18551      0

# %%
train_df['label'].hist()
train_df['label'].value_counts()
# Out:
# 0    5160
# 2    4230
# 1    1950
# 3     697
# 4     566
# Name: label, dtype: int64

# %%
import os
import shutil

def cpfile(dirname):
    path = './'+ dirname +'/'
    for root, dirs, files in os.walk(path):  # replace the . with your starting directory
        for file in files:
            if file[-5:] == '.jpeg':
                path_file = os.path.join(root,file)
                shutil.copy2(path_file,path) # change you destination dir
        
if __name__ == "__main__":
    cpfile('training')
    cpfile('testing')
# Out:
# ---------------------------------------------------------------------------
# SameFileError                             Traceback (most recent call last)
# <ipython-input-10-1f34d1007019> in <module>
#      11
#      12 if __name__ == "__main__":
# ---> 13     cpfile('training')
#      14     cpfile('testing')
#
# <ipython-input-10-1f34d1007019> in cpfile(dirname)
#       8             if file[-5:] == '.jpeg':
#       9                 path_file = os.path.join(root,file)
# ---> 10                 shutil.copy2(path_file,path) # change you destination dir
#      11
#      12 if __name__ == "__main__":
#
# ~\Anaconda3\envs\tfgpu\lib\shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
#     265     return dst
#
# ~\Anaconda3\envs\tfgpu\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     102     """
#     103     if _samefile(src, dst):
# --> 104         raise SameFileError("{!r} and {!r} are the same file".format(src, dst))
#     105
#     106     for fn in [src, dst]:
#
# SameFileError: './training/0_34.jpeg' and './training/0_34.jpeg' are the same file

# %%
img = cv2.imread('./training/0_34.jpeg',0)
plt.imshow(img)

# %%
def display_samples(df, columns=4, rows=3):
    fig=plt.figure(figsize=(5*columns, 4*rows))

    for i in range(columns*rows):
        image_path = df.loc[i,'data']
        image_id = df.loc[i,'label']
        img = cv2.imread('./training/{image_path}.jpeg'.format(image_path=image_path))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        fig.add_subplot(rows, columns, i+1)
        plt.title(image_id)
        plt.imshow(img)
    
    plt.tight_layout()

display_samples(train_df)

# %%
def get_pad_width(im, new_shape, is_rgb=True):
    pad_diff = new_shape - im.shape[0], new_shape - im.shape[1]
    t, b = math.floor(pad_diff[0]/2), math.ceil(pad_diff[0]/2)
    l, r = math.floor(pad_diff[1]/2), math.ceil(pad_diff[1]/2)
    if is_rgb:
        pad_width = ((t,b), (l,r), (0, 0))
    else:
        pad_width = ((t,b), (l,r))
    return pad_width

def preprocess_image(image_path, desired_size=224):
    im = Image.open(image_path)
    im = im.resize((desired_size, )*2, resample=Image.LANCZOS)
    
    return im

# %%
N = train_df.shape[0]
x_train = np.empty((N, 224, 224, 3), dtype=np.uint8)

for i, image_id in enumerate(tqdm(train_df['data'])):
    x_train[i, :, :, :] = preprocess_image(
        './training/{image_id}.jpeg'.format(image_id=image_id))
# Out:
# 100%|██████████| 12603/12603 [08:40<00:00, 23.60it/s]

# %%
N = test_df.shape[0]
x_test = np.empty((N, 224, 224, 3), dtype=np.uint8)

for i, image_id in enumerate(tqdm(test_df['data'])):
    x_test[i, :, :, :] = preprocess_image(
        './testing/{image_id}.jpeg'.format(image_id=image_id))
# Out:
# 100%|██████████| 3153/3153 [02:09<00:00, 24.40it/s]

# %%
y_train = train_df.iloc[:,1]
y_test = test_df.iloc[:,1]

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (12603, 224, 224, 3)
# (12603,)
# (3153, 224, 224, 3)
# (3153,)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, 
    test_size=0.15, 
    random_state=2019
)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([4395, 1667, 3583,  592,  475]))

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([1290,  488, 1058,  175,  142]))

# %%
y_train.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-7276899eb410> in <module>
# ----> 1 y_train.unique()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'unique'

# %%
densenet = DenseNet121(
    weights='./DenseNet-BC-121-32-no-top.h5',
    include_top=False,
    input_shape=(224,224,3)
)

# %% [markdown]
# # Edited Point Loss Wrapper

# %%
# example Keras wrapper for hp_point_loss

def get_ohpl_wrapper (loandup):
    l,u=loandup
    def ohpl(y_true, y_pred):
        return hp_point_loss(y_true, y_pred, l, u)
    return ohpl

# %%
# example Keras wrapper for hp_ordering_loss

def get_ordering_wrapper (min_label, max_label, margin):
    def ohpl(y_true, y_pred):
        return hp_ordering_loss(y_true, y_pred)
    return ohpl


hp_ordering_loss = get_ordering_wrapper(0,4, 0.1)

# %% [markdown]
# # Margin function

# %%
# centers is training set centers see 'train_cent' above
# margin is the point margin
# num_ords is the number of unique ordinal label values

def ohpl_margins(centers, num_ords, margin=0.1):
    inner_ord_array = np.ones(num_ords - 1).reshape(-1,1)
    up = np.concatenate((inner_ord_array*margin, [[1e9]]), axis=0)+centers
    lo = centers-np.concatenate(([[1e9]], inner_ord_array*margin), axis=0)

    return lo, up

# %%
def build_model():
    model = Sequential()
    model.add(densenet)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dense(1))


    
    return model

# %%
model = build_model()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 8,088,129
# Trainable params: 8,004,481
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
# Compiled Model For Stage 1 Ordering Loss

# %%
model.compile(
    loss=hp_ordering_loss,
    #loss='binary_crossentropy',
    optimizer=Adam(lr=0.0003),
    #metrics=['accuracy']
    )

# %% [markdown]
# ## Training and Evaluation Stage 1

# %%
#Stage 1: hyperplane ordering loss

# create matrix that subtracts adjacent vector values cDiff is that matrix
labels, freq = np.unique(y_train, return_counts=True)
ords = labels.reshape(-1, 1)
l = min(labels)
u = max(labels)
labs = len(labels)
ord_wgt = 1.25

eyes = np.eye(labs)
cDiff = eyes[1:labs,:]-eyes[:(labs-1),:]


while mingap < 1.0:
    # fit model

    train_out = model.predict(X_train)

    train_cent = np.matmul(Ytrain,train_out)

    mingap = np.min(np.matmul(cDiff,train_cent))
    
    

labels, freq = np.unique(y_train, return_counts=True)
ords = labels.reshape(-1, 1)
l = min(labels)
u = max(labels)
labs = len(labels)
ord_wgt = 1.25

eyes = np.eye(labs)
cDiff = eyes[1:labs,:]-eyes[:(labs-1),:]

mingap = 0.0
i = 0
while mingap < 1.0:

    history = model.fit(
        x_train, y_train, batch_size=24,
        epochs=10,
        #steps_per_epoch=x_train.shape[0] / batch_size,
        validation_data=(x_val, y_val),
        #callbacks=[kappa_metrics]
    )

    train_cent = np.matmul(Ytrain,train_out)
    mingap = np.min(np.matmul(cDiff,train_cent))
    print('Minimum gap is: ', mingap)
# Out:
# Train on 10712 samples, validate on 1891 samples
# Epoch 1/15
# 10712/10712 [==============================] - 214s 20ms/step - loss: 5.7667 - val_loss: 5.5948
# Epoch 2/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 5.8482 - val_loss: 5.9739
# Epoch 3/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 5.2645 - val_loss: 8.7034
# Epoch 4/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 5.2717 - val_loss: 6.9487
# Epoch 5/15
# 10712/10712 [==============================] - 166s 16ms/step - loss: 5.2192 - val_loss: 9.5665
# Epoch 6/15
# 10712/10712 [==============================] - 166s 16ms/step - loss: 5.8733 - val_loss: 6.7485
# Epoch 7/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 5.3603 - val_loss: 8.7753
# Epoch 8/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 5.4566 - val_loss: 5.8100
# Epoch 9/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 4.7946 - val_loss: 5.8005
# Epoch 10/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 4.7495 - val_loss: 6.3545
# Epoch 11/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 5.2051 - val_loss: 6.1122
# Epoch 12/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 4.9266 - val_loss: 6.5312
# Epoch 13/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 5.4072 - val_loss: 6.3916
# Epoch 14/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 4.9523 - val_loss: 5.4300
# Epoch 15/15
# 10712/10712 [==============================] - 167s 16ms/step - loss: 4.8715 - val_loss: 6.0845

# %%
y_train.shape
# Out:
# (10712,)

# %%
y_train[:5]
# Out:
# array([0, 1, 0, 1, 2])

# %%
y_test[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
# Define the minimum class
min_class = min(y_train.unique())
y_train = np.array(y_train)

# %% [markdown]
# # Edited to add valdation set One Hot

# %%
# Create matrix from on hot encoded training labels to use to calculate class centroids
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False)
onehot = onehot_encoder.fit_transform(y_train.reshape((-1, 1)))
valhot = onehot_encoder.fit_transform(y_val.reshape((-1, 1)))
onehot_inverse = 1/np.sum((onehot.T), axis=1)
new_y_train = onehot.T*onehot_inverse.reshape(-1,1)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """

# %%
# Score the training set
pred = model.predict(x_train, batch_size=24)

# %%
print(x_train.shape)
print(pred.shape)
print(new_y_train.shape)
# Out:
# (10712, 224, 224, 3)
# (10712, 1)
# (5, 10712)

# %%
print(pred[:20])
print(new_y_train.T[:20])
# Out:
# [[  -58.966267]
#  [  -58.20739 ]
#  [  -58.340363]
#  [  -59.293488]
#  [  -59.434036]
#  [  -93.11518 ]
#  [  -58.370052]
#  [  -58.317825]
#  [  -58.434097]
#  [  -57.949932]
#  [  -58.406822]
#  [  -58.189354]
#  [  -58.06332 ]
#  [-2610.277   ]
#  [  -57.95331 ]
#  [  -59.579998]
#  [  -58.666363]
#  [  -58.21123 ]
#  [  -58.927795]
#  [  -60.782684]]
# [[0.00022753 0.         0.         0.         0.        ]
#  [0.         0.00059988 0.         0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.         0.00059988 0.         0.         0.        ]
#  [0.         0.         0.0002791  0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.         0.00059988 0.         0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.         0.         0.0002791  0.         0.        ]
#  [0.         0.         0.         0.00168919 0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.         0.         0.0002791  0.         0.        ]
#  [0.         0.         0.0002791  0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.         0.         0.0002791  0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]
#  [0.         0.         0.0002791  0.         0.        ]
#  [0.00022753 0.         0.         0.         0.        ]]

# %%
# Multiply centroid calculation matrix, new_y_train, by training set scores
train_cent = np.matmul(new_y_train, pred)

# %%
train_cent.shape
# Out:
# (5, 1)

# %% [markdown]
# ## <font color='red'>the result of train_cent dosen't look right, since it's ordinal classfication so i assume the value should be increment</font>

# %%
train_cent
# Out:
# array([[-1788.1947302 ],
#        [-1060.37331001],
#        [-1699.54777096],
#        [-1228.94274163],
#        [-2781.58812835]])

# %% [markdown]
# # Edited to Add State 2 Point loss
# ## Note Point loss is defined here

# %%
# generate list of ordinal values, use length as ord count in ohpl_margins function
ords = np.unique(y_train)

point_loss = get_ohpl_wrapper(ohpl_margins(train_cent, len(ords), 0.1))

# %%
# Recompile Model with point loss 

model.compile(
    loss=point_loss,
    #loss='binary_crossentropy',
    optimizer=Adam(lr=0.0003),
    #metrics=['accuracy']
    )

# %% [markdown]
# ## Edited Training and Evaluation Stage 2

# %%
# Stage :2 hyperplane point loss

batch_size=24
history = model.fit(
    x_train, onehot, batch_size=24,
    epochs=15,
    #steps_per_epoch=x_train.shape[0] / batch_size,
    validation_data=(x_val, valhot),
    #callbacks=[kappa_metrics]
)
# Out:
# Train on 10712 samples, validate on 1891 samples
# Epoch 1/15
# 10712/10712 [==============================] - 224s 21ms/step - loss: 8301.8849 - val_loss: 5568.6448
# Epoch 2/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4487.4491 - val_loss: 3903.7240
# Epoch 3/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4420.0762 - val_loss: 3905.3560
# Epoch 4/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4420.7181 - val_loss: 4387.1778
# Epoch 5/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4359.0732 - val_loss: 3825.1843
# Epoch 6/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4352.3779 - val_loss: 3857.3855
# Epoch 7/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4323.8600 - val_loss: 3907.7813
# Epoch 8/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4319.6183 - val_loss: 3921.7276
# Epoch 9/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4331.0958 - val_loss: 3818.1893
# Epoch 10/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4295.1297 - val_loss: 3850.2384
# Epoch 11/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4317.7266 - val_loss: 3847.3967
# Epoch 12/15
# 10712/10712 [==============================] - 169s 16ms/step - loss: 4285.3836 - val_loss: 3820.4069
# Epoch 13/15
# 10712/10712 [==============================] - 169s 16ms/step - loss: 4263.6558 - val_loss: 3861.8797
# Epoch 14/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4261.5825 - val_loss: 3890.3735
# Epoch 15/15
# 10712/10712 [==============================] - 170s 16ms/step - loss: 4233.1645 - val_loss: 3899.0033

# %%
# Calculate new data model score
new_pred = model.predict(x_test)

# %%
# Identify the closest centroid
rcenter = train_cent.T # create row matrix of centroids
y_pred = np.argmin(abs(new_pred - rcenter), axis=1) + min_class

# %%
print(new_pred.shape)
print(rcenter.shape)
print(min_class.shape)
print(rcenter)
# Out:
# (3153, 1)
# (1, 5)
# ()
# [[-1788.1947302  -1060.37331001 -1699.54777096 -1228.94274163
#   -2781.58812835]]

# %%
# calculate the mean absolute error and mean zero one error
mae = np.mean(abs(y_pred - y_test))
mze = np.mean(abs(y_pred - y_test) > 0)   
print(mae, mze)
# Out:
# 1.0076117982873454 0.5601014906438313

# %% [markdown]
# ## <font color='red'>the confusion matrix shows it predict all the data either 0 or 2</font>

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
print('Confusion Matrix')
print(confusion_matrix(y_test, y_pred))
print('Classification Report')
target_names = ['0', '1', '2', '3', '4']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[890   0 400   0   0]
#  [317   0 171   0   0]
#  [561   0 497   0   0]
#  [ 86   0  89   0   0]
#  [ 68   0  74   0   0]]
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.46      0.69      0.55      1290
#           1       0.00      0.00      0.00       488
#           2       0.40      0.47      0.43      1058
#           3       0.00      0.00      0.00       175
#           4       0.00      0.00      0.00       142
#
# avg / total       0.32      0.44      0.37      3153
# /usr/local/lib/python3.5/dist-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.metrics import cohen_kappa_score, confusion_matrix


print( confusion_matrix(y_test, y_pred))
cohen_kappa_score(y_test, y_pred, weights='linear'), cohen_kappa_score(y_test, y_pred, weights='quadratic'),
# Out:
# [[890   0 400   0   0]
#  [317   0 171   0   0]
#  [561   0 497   0   0]
#  [ 86   0  89   0   0]
#  [ 68   0  74   0   0]]
# (0.12494484541472439, 0.14751547224058426)

# %%
y_pred.shape
# Out:
# (3153,)

# %% [markdown]
# ## <font color='red'>I print some result of the pridiction, shows the prediction value mainly ranged from -1800 to -1700. i think that's the reason for the prediction result.</font>

# %%
print(np.unique(y_test, return_counts=True))
print(np.unique(y_pred, return_counts=True))
print(new_pred[:40])
#print(y_pred[2000:2200])
# Out:
# (array([0, 1, 2, 3, 4]), array([1290,  488, 1058,  175,  142]))
# (array([0, 2]), array([1922, 1231]))
# [[-1781.8966]
#  [-1744.3153]
#  [-1750.519 ]
#  [-1756.7847]
#  [-1800.5302]
#  [-1776.1964]
#  [-1727.9576]
#  [-1756.1201]
#  [-1813.3931]
#  [-1791.6553]
#  [-1777.302 ]
#  [-1744.6111]
#  [-1730.9225]
#  [-1724.6934]
#  [-1753.7098]
#  [-1779.7694]
#  [-1795.4427]
#  [-1743.4568]
#  [-1733.4736]
#  [-1774.4032]
#  [-1763.7787]
#  [-1727.2096]
#  [-1777.4587]
#  [-1750.784 ]
#  [-1748.6632]
#  [-1790.2963]
#  [-1700.0114]
#  [-1719.6708]
#  [-1730.3464]
#  [-1742.582 ]
#  [-1736.3754]
#  [-1744.9934]
#  [-1791.7748]
#  [-1749.8864]
#  [-1776.0693]
#  [-1754.2078]
#  [-1747.427 ]
#  [-1740.535 ]
#  [-1783.717 ]
#  [-1759.4679]]

# %%
confusion_matrix(y_test, y_pred)
